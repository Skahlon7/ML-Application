# %%
#America 
import pandas as pd 
import numpy as np 
import seaborn as sns 
abort_df = pd.read_csv('/Users/Mirzafamily/Desktop/ML-Application/Abortion.csv')
amer_df = abort_df[abort_df['country'] == 'United States of America']

killed = amer_df.groupby('country').agg({'numberofabortions': sum })
print(killed.iloc[[0]])
# Out:
#                           numberofabortions
# country
# United States of America         78700922.0

# %%
list_scode = list(set(abort_df['country']))
list_scode.sort()
#list_scode
# Out:
# ['Albania',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Bhutan',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Canada',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Dominican Republic',
#  'Egypt',
#  'England and Wales',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'French Guiana',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guadeloupe',
#  'Guatemala',
#  'Haiti',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Kazakhstan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Latvia',
#  'Lithuania',
#  'Malawi',
#  'Martinique',
#  'Mayotte',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Myanmar',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Réunion',
#  'Scotland',
#  'Senegal',
#  'Serbia',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Tonga',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Viet Nam',
#  'Zimbabwe']

# %%
import plotly.graph_objects as go

#interactive plot of abortion timeline from df. 
pal = list(sns.color_palette(palette = 'viridis', n_colors = len(list_scode)).as_hex())

fig = go.Figure()
for d, p in zip(list_scode, pal): 
    fig.add_trace(go.Scatter(x = abort_df[abort_df['country']==d]['yearstart'],
                             y = abort_df[abort_df['country']==d]['numberofabortions'],
                             name = d,
                             line_color = p,
                             fill = None)) 
fig.show()
# Out:
# <div>                            <div id="bbbb9102-fd62-4218-8842-3676c9b40cc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbbb9102-fd62-4218-8842-3676c9b40cc7")) {                    Plotly.newPlot(                        "bbbb9102-fd62-4218-8842-3676c9b40cc7",                        [{"line":{"color":"#450457"},"name":"Albania","x":[1990,1991,1992,1993,1994,1994,1995,1995,1996,1996,1997,1997,1998,1998,1999,1999,2000,2000,2001,2001,2002,2002,2003,2003,2004,2004,2005,2005,2006,2006,2007,2007,2008,2008,2008,2009,2009,2008,2009,2010,2010,2010,2011,2011,2011,2012,2012,2012,2012,2013,2013,2013,2014,2014,2015,2015,2016,2016,2017],"y":[17400.0,20300.0,18700.0,25100.0,31622.0,22800.0,22400.0,31874.0,21180.0,32538.0,15705.0,22103.0,18944.0,12679.0,13951.0,19930.0,21004.0,9869.0,17125.0,9122.0,17500.0,8756.0,6890.0,12087.0,10517.0,6890.0,4647.0,9403.0,9552.0,4513.0,9030.0,4076.0,3927.0,8335.0,3927.0,8139.0,3675.0,null,3554.0,2267.0,2636.0,6919.0,7042.0,2395.0,1885.0,1766.0,2031.0,2699.0,6755.0,1457.0,2177.0,6442.0,1679.0,5572.0,5619.0,1433.0,1203.0,1206.0,1193.0],"type":"scatter"},{"line":{"color":"#46075a"},"name":"Argentina","x":[2000],"y":[371965.0],"type":"scatter"},{"line":{"color":"#460b5e"},"name":"Armenia","x":[1990,1990,1991,1992,1993,1994,1995,1995,1995,1996,1997,1997,1998,1998,1999,1999,2000,2000,2000,2000,2001,2001,2002,2002,2003,2003,2003,2004,2004,2005,2005,2005,2005,2006,2006,2006,2007,2007,2007,2008,2008,2008,2009,2009,2009,2010,
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
table = world.merge(abort_df, how = 'left', left_on = ['name'], right_on = ['country'])
table
# Out:
#          pop_est      continent                 name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                 Fiji    FJI        5496
# 1     58005463.0         Africa             Tanzania    TZA       63177
# 2       603253.0         Africa            W. Sahara    ESH         907
# 3     37589262.0  North America               Canada    CAN     1736425
# 4     37589262.0  North America               Canada    CAN     1736425
# ...          ...            ...                  ...    ...         ...
# 2928    622137.0         Europe           Montenegro    MNE        5542
# 2929    622137.0         Europe           Montenegro    MNE        5542
# 2930   1794248.0         Europe               Kosovo    KOS        7926
# 2931   1394973.0  North America  Trinidad and Tobago    TTO       24269
# 2932  11062113.0         Africa             S. Sudan    SSD       11998
#
#                                                geometry     country    iso  \
# 0     MULTIPOLYGON (((180.00000 -16.06713, 180.00000...         NaN    NaN
# 1     POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...    Tanzania  834.0
# 2     POLYGON ((-8.66559 27.65643, -8.66512 27.58948...         NaN    NaN
# 3     MULTIPOLYGON (((-122.84000 49.00000, -122.9742...      Canada  124.0
# 4     MULTIPOLYGON (((-122.84000 49.00000, -122.9742...      Canada  124.0
# ...                                                 ...         ...    ...
# 2928  POLYGON ((20.07070 42.58863, 19.80161 42.50009...  Montenegro  499.0
# 2929  POLYGON ((20.07070 42.58863, 19.80161 42.50009...  Montenegro  499.0
# 2930  POLYGON ((20.59025 41.85541, 20.52295 42.21787...         NaN    NaN
# 2931  POLYGON ((-61.68000 10.76000, -61.10500 10.890...         NaN    NaN
# 2932  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...         NaN    NaN
#
#       yearstart  yearend  ... abortionrate perc_p_ending_in_a  spontaneous  \
# 0           NaN      NaN  ...          NaN                NaN          NaN
# 1        2013.0   2013.0  ...         36.1                NaN           No
# 2           NaN      NaN  ...          NaN                NaN          NaN
# 3        1990.0   1990.0  ...          NaN                NaN           No
# 4        1990.0   1990.0  ...          NaN                NaN           No
# ...         ...      ...  ...          ...                ...          ...
# 2928     2015.0   2015.0  ...          NaN                NaN           No
# 2929     2016.0   2016.0  ...          NaN                NaN           No
# 2930        NaN      NaN  ...          NaN                NaN          NaN
# 2931        NaN      NaN  ...          NaN                NaN          NaN
# 2932        NaN      NaN  ...          NaN                NaN          NaN
#
#                  datatype         datasource    complete classification  \
# 0                     NaN                NaN         NaN            NaN
# 1                   Study   Keogh et al 2015         NaN            NaN
# 2                     NaN                NaN         NaN            NaN
# 3     Official Statistics  Statistics Canada    Complete            NaN
# 4     Official Statistics               UNSD  Incomplete        Outlier
# ...                   ...                ...         ...            ...
# 2928  Official Statistics               UNSD    Complete            NaN
# 2929  Official Statistics               UNSD    Complete            NaN
# 2930                  NaN                NaN         NaN            NaN
# 2931                  NaN                NaN         NaN            NaN
# 2932                  NaN                NaN         NaN            NaN
#
#      modelused marriedonly notes
# 0          NaN         NaN   NaN
# 1          Yes   All women   NaN
# 2          NaN         NaN   NaN
# 3          Yes         NaN   NaN
# 4          NaN         NaN   NaN
# ...        ...         ...   ...
# 2928       Yes         NaN   NaN
# 2929       Yes         NaN   NaN
# 2930       NaN         NaN   NaN
# 2931       NaN         NaN   NaN
# 2932       NaN         NaN   NaN
#
# [2933 rows x 23 columns]
