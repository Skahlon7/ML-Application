# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('/Users/sandeepk/Desktop/DS612/ShenyangPM20100101_20151231.csv')

# %%
#Goals:
#LINEAR #PLOT
#MULTIVARIATE WITH OPTIMIZATION OF PARAMETERS (LR, RIDGE, LASSO)
#KNN (CBWD) #PLOT

#Logistic to predict what day?

# %%
df
# Out:
#           No  year  month  day  hour  season  PM_Taiyuanjie  PM_US Post  \
# 0          1  2010      1    1     0       4            NaN         NaN
# 1          2  2010      1    1     1       4            NaN         NaN
# 2          3  2010      1    1     2       4            NaN         NaN
# 3          4  2010      1    1     3       4            NaN         NaN
# 4          5  2010      1    1     4       4            NaN         NaN
# ...      ...   ...    ...  ...   ...     ...            ...         ...
# 52579  52580  2015     12   31    19       4          162.0       166.0
# 52580  52581  2015     12   31    20       4          255.0       259.0
# 52581  52582  2015     12   31    21       4          266.0       368.0
# 52582  52583  2015     12   31    22       4          202.0       319.0
# 52583  52584  2015     12   31    23       4            NaN       275.0
#
#        PM_Xiaoheyan  DEWP   HUMI    PRES  TEMP cbwd      Iws  precipitation  \
# 0               NaN -26.0  69.79  1024.0 -22.0   NE   1.0289            NaN
# 1               NaN -26.0  76.26  1024.0 -23.0   NE   2.5722            NaN
# 2               NaN -27.0  69.56  1023.0 -23.0   NE   5.1444            NaN
# 3               NaN -27.0  69.56  1023.0 -23.0   NE   7.7166            NaN
# 4               NaN -27.0  69.56  1022.0 -23.0   NE   9.7744            NaN
# ...             ...   ...    ...     ...   ...  ...      ...            ...
# 52579         435.0 -10.0  92.42  1031.0  -9.0   SE   2.0000            0.0
# 52580         429.0 -10.0  79.10  1030.0  -7.0   SE   5.0000            0.0
# 52581         361.0 -10.0  79.10  1030.0  -7.0   SE   8.0000            0.0
# 52582         342.0 -10.0  79.10  1028.0  -7.0   SE  11.0000            NaN
# 52583           NaN  -9.0  79.26  1028.0  -6.0   SE  12.0000            0.0
#
#        Iprec
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 52579    0.0
# 52580    0.0
# 52581    0.0
# 52582    NaN
# 52583    0.0
#
# [52584 rows x 17 columns]

# %%
#Recieve na reporting
ls = list(df.columns)
for x in ls:
  if sum(df[x].isna()) > 0:
    print(x)
    print(sum(df[x].isna()))
    print()
# Out:
# PM_Taiyuanjie
# 28196
#
# PM_US Post
# 30904
#
# PM_Xiaoheyan
# 27957
#
# DEWP
# 692
#
# HUMI
# 680
#
# PRES
# 692
#
# TEMP
# 692
#
# cbwd
# 692
#
# Iws
# 692
#
# precipitation
# 12763
#
# Iprec
# 12763

# %%
#copy below later
df = df[df['DEWP'].isna() == False]
df = df[df['TEMP'].isna() == False]
df
# Out:
#           No  year  month  day  hour  season  PM_Taiyuanjie  PM_US Post  \
# 0          1  2010      1    1     0       4            NaN         NaN
# 1          2  2010      1    1     1       4            NaN         NaN
# 2          3  2010      1    1     2       4            NaN         NaN
# 3          4  2010      1    1     3       4            NaN         NaN
# 4          5  2010      1    1     4       4            NaN         NaN
# ...      ...   ...    ...  ...   ...     ...            ...         ...
# 52579  52580  2015     12   31    19       4          162.0       166.0
# 52580  52581  2015     12   31    20       4          255.0       259.0
# 52581  52582  2015     12   31    21       4          266.0       368.0
# 52582  52583  2015     12   31    22       4          202.0       319.0
# 52583  52584  2015     12   31    23       4            NaN       275.0
#
#        PM_Xiaoheyan  DEWP   HUMI    PRES  TEMP cbwd      Iws  precipitation  \
# 0               NaN -26.0  69.79  1024.0 -22.0   NE   1.0289            NaN
# 1               NaN -26.0  76.26  1024.0 -23.0   NE   2.5722            NaN
# 2               NaN -27.0  69.56  1023.0 -23.0   NE   5.1444            NaN
# 3               NaN -27.0  69.56  1023.0 -23.0   NE   7.7166            NaN
# 4               NaN -27.0  69.56  1022.0 -23.0   NE   9.7744            NaN
# ...             ...   ...    ...     ...   ...  ...      ...            ...
# 52579         435.0 -10.0  92.42  1031.0  -9.0   SE   2.0000            0.0
# 52580         429.0 -10.0  79.10  1030.0  -7.0   SE   5.0000            0.0
# 52581         361.0 -10.0  79.10  1030.0  -7.0   SE   8.0000            0.0
# 52582         342.0 -10.0  79.10  1028.0  -7.0   SE  11.0000            NaN
# 52583           NaN  -9.0  79.26  1028.0  -6.0   SE  12.0000            0.0
#
#        Iprec
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 52579    0.0
# 52580    0.0
# 52581    0.0
# 52582    NaN
# 52583    0.0
#
# [51892 rows x 17 columns]

# %% [markdown]
# ## LINEAR REGRESSION
# - Predictor: Dew Point
# - Outcome: Temperature

# %%
df1 = df.copy()
x = df1['DEWP']
y = df1['TEMP']
print ('Correlation(x, y) = ',np.corrcoef(x,y)[0,1])

#Positive Linear Relationship
# Out:
# Correlation(x, y) =  0.9095702332955348

# %%
#Visualization of relationship (Dew Point + Temperature)
df1 = df.copy()

df1 = df1[df1['DEWP'] > df1['DEWP'].min()]

x = df1['DEWP']
y = df1['TEMP']

plt.xlabel("Dew Point")
plt.ylabel("Temperature (C)")

plt.plot(x,y, 'o')

plt.show()

# %% [markdown]
# ## Develop ML Linear Regression Model

# %%
#Model Development
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

x_train = x_train.values.reshape(-1,1)

x_test = x_test.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score 

my_LR = LinearRegression().fit(x_train, y_train)

print("Slope bo:", my_LR.intercept_)
print("Coefficient b1:", my_LR.coef_[0])
# Out:
# Slope bo: 7.700492881784548
# Coefficient b1: 0.8908584789253008

# %%
#Performance Evaluation
y_train_predict = my_LR.predict(x_train)

r2_train =  r2_score(y_train, y_train_predict)
print ("R_squared for training set = ", r2_train)

y_predict = my_LR.predict(x_test)

r2_test = r2_score(y_test, y_predict)
print ("R_squared for test set = ", r2_test)
# Out:
# R_squared for training set =  0.8276343828714587
# R_squared for test set =  0.8296699648826955

# %%
r2_LR_df = pd.DataFrame()
r2_LR_df["LR"]= [r2_train, r2_test]
r2_LR_df.rename(index={0:"Train", 1: "Test"})
# Out:
#              LR
# Train  0.827634
# Test   0.829670

# %% [markdown]
# ## Prediction

# %%
#User-input

lst = []
pred_lst = []

validation = "Y"
while validation == "Y":
    choice = float(input("Enter Dew Point: "))
    lst.append(choice)
    validation = input("Enter another value? (Y/N): ").upper()
    
for x in lst:
    pred = my_LR.predict([[x]])[0]
    pred_lst.append(pred)

user_df = pd.DataFrame()
user_df["Dew Point"] = lst
user_df["Temp_pred"] = pred_lst

user_df.round(2)
# Out:
# Enter Dew Point: -1
# Enter another value? (Y/N): y
# Enter Dew Point: -22
# Enter another value? (Y/N): y
# Enter Dew Point: -3
# Enter another value? (Y/N): n
#    Dew Point  Temp_pred
# 0       -1.0       6.81
# 1      -22.0     -11.90
# 2       -3.0       5.03

# %%
#Visualization of Linear Regression Trend
plt.xlabel("Dew Point")
plt.ylabel("Temperature (C)")

plt.plot(x, y, 'o')
plt.plot(x_test,y_predict)
plt.show()

# %% [markdown]
# ## Multiple Regression

# %%
#Correlation matrix of optimal predictors
df[["DEWP", "season", "PRES", "TEMP"]].corr()
# Out:
#             DEWP    season      PRES      TEMP
# DEWP    1.000000 -0.452545 -0.798468  0.909570
# season -0.452545  1.000000  0.556422 -0.556397
# PRES   -0.798468  0.556422  1.000000 -0.798020
# TEMP    0.909570 -0.556397 -0.798020  1.000000

# %%
# Out:
#                      No      year     month       day      hour    season  \
# No             1.000000  0.985764  0.165798  0.016665  0.000043  0.028588
# year           0.985764  1.000000 -0.001775  0.001007 -0.000437 -0.007153
# month          0.165798 -0.001775  1.000000  0.010170  0.000140  0.208707
# day            0.016665  0.001007  0.010170  1.000000 -0.000507 -0.013272
# hour           0.000043 -0.000437  0.000140 -0.000507  1.000000 -0.001152
# season         0.028588 -0.007153  0.208707 -0.013272 -0.001152  1.000000
# PM_Taiyuanjie -0.075914 -0.060512 -0.062934  0.086149 -0.052748  0.246670
# PM_US Post     0.093802  0.065064  0.067899  0.082752 -0.071571  0.270267
# PM_Xiaoheyan  -0.064419 -0.059009 -0.032957  0.079228 -0.055921  0.279629
# DEWP           0.049156  0.007360  0.250970  0.022853  0.003428 -0.452545
# HUMI          -0.066606 -0.098705  0.182859  0.011002 -0.242251  0.105354
# PRES          -0.013568 -0.003853 -0.061499  0.001387 -0.021039  0.556422
# TEMP           0.086482  0.055129  0.192867  0.021694  0.104968 -0.556397
# Iws            0.061942  0.066957 -0.024899  0.012155  0.068418 -0.135503
# precipitation -0.044327 -0.046423  0.015976 -0.007943 -0.002213 -0.030527
# Iprec         -0.065032 -0.068117  0.023565 -0.013771 -0.003694 -0.029413
#
#                PM_Taiyuanjie  PM_US Post  PM_Xiaoheyan      DEWP      HUMI  \
# No                 -0.075914    0.093802     -0.064419  0.049156 -0.066606
# year               -0.060512    0.065064     -0.059009  0.007360 -0.098705
# month              -0.062934    0.067899     -0.032957  0.250970  0.182859
# day                 0.086149    0.082752      0.079228  0.022853  0.011002
# hour               -0.052748   -0.071571     -0.055921  0.003428 -0.242251
# season              0.246670    0.270267      0.279629 -0.452545  0.105354
# PM_Taiyuanjie       1.000000    0.923943      0.923609 -0.214553  0.195563
# PM_US Post          0.923943    1.000000      0.921474 -0.240081  0.196816
# PM_Xiaoheyan        0.923609    0.921474      1.000000 -0.253465  0.180203
# DEWP               -0.214553   -0.240081     -0.253465  1.000000  0.410693
# HUMI                0.195563    0.196816      0.180203  0.410693  1.000000
# PRES                0.299043    0.365827      0.342262 -0.798468 -0.185646
# TEMP               -0.320530   -0.355343     -0.357403  0.909570  0.007854
# Iws                -0.060139   -0.078394     -0.072829  0.003258 -0.183712
# precipitation      -0.033061   -0.035878     -0.041249  0.098391  0.128073
# Iprec              -0.050070   -0.063613     -0.059110  0.099834  0.146287
#
#                    PRES      TEMP       Iws  precipitation     Iprec
# No            -0.013568  0.086482  0.061942      -0.044327 -0.065032
# year          -0.003853  0.055129  0.066957      -0.046423 -0.068117
# month         -0.061499  0.192867 -0.024899       0.015976  0.023565
# day            0.001387  0.021694  0.012155      -0.007943 -0.013771
# hour          -0.021039  0.104968  0.068418      -0.002213 -0.003694
# season         0.556422 -0.556397 -0.135503      -0.030527 -0.029413
# PM_Taiyuanjie  0.299043 -0.320530 -0.060139      -0.033061 -0.050070
# PM_US Post     0.365827 -0.355343 -0.078394      -0.035878 -0.063613
# PM_Xiaoheyan   0.342262 -0.357403 -0.072829      -0.041249 -0.059110
# DEWP          -0.798468  0.909570  0.003258       0.098391  0.099834
# HUMI          -0.185646  0.007854 -0.183712       0.128073  0.146287
# PRES           1.000000 -0.798020 -0.094658      -0.098100 -0.101463
# TEMP          -0.798020  1.000000  0.084575       0.052402  0.047719
# Iws           -0.094658  0.084575  1.000000      -0.014021 -0.012922
# precipitation -0.098100  0.052402 -0.014021       1.000000  0.457509
# Iprec         -0.101463  0.047719 -0.012922       0.457509  1.000000
